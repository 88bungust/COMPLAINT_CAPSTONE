# %%
import pandas as pd

# %%
complaints = pd.read_csv("COMPLAINTS SHEET 2.csv")
complaints
# Out:
#        Date received                                 Company State ZIP code  \
# 0         12/31/2018     Experian Information Solutions Inc.    TX    77072
# 1         12/31/2018                    JPMORGAN CHASE & CO.   NaN      NaN
# 2         12/31/2018                           EQUIFAX, INC.    FL    330XX
# 3         12/31/2018  TRANSUNION INTERMEDIATE HOLDINGS, INC.    GA    30342
# 4         12/31/2018        MERCEDES BENZ FINANCIAL SERVICES    CA      NaN
# ...              ...                                     ...   ...      ...
# 257374      1/1/2018         Resurgent Capital Services L.P.    IN    47714
# 257375      1/1/2018                           EQUIFAX, INC.    LA    703XX
# 257376      1/1/2018                          Coinbase, Inc.    NJ    074XX
# 257377      1/1/2018                          Coinbase, Inc.   NaN      NaN
# 257378      1/1/2018            WHEELS FINANCIAL GROUP, LLC.    PA      NaN
#
#                  Tags Consumer consent provided? Submitted via  \
# 0                 NaN       Consent not provided           Web
# 1                 NaN                        NaN         Phone
# 2                 NaN                      Other           Web
# 3                 NaN                        NaN      Referral
# 4                 NaN           Consent provided           Web
# ...               ...                        ...           ...
# 257374            NaN       Consent not provided           Web
# 257375            NaN           Consent provided           Web
# 257376            NaN           Consent provided           Web
# 257377            NaN           Consent provided           Web
# 257378  Servicemember           Consent provided           Web
#
#        Date sent to company Company response to consumer Timely response?  \
# 0                12/31/2018      Closed with explanation              Yes
# 1                  1/3/2019      Closed with explanation              Yes
# 2                12/31/2018      Closed with explanation              Yes
# 3                12/31/2018      Closed with explanation              Yes
# 4                12/31/2018      Closed with explanation              Yes
# ...                     ...                          ...              ...
# 257374             1/3/2018      Closed with explanation              Yes
# 257375             1/1/2018      Closed with explanation              Yes
# 257376             1/1/2018      Closed with explanation              Yes
# 257377             1/3/2018      Closed with explanation              Yes
# 257378            1/17/2018      Closed with explanation              Yes
#
#         Consumer disputed?  Complaint ID
# 0                      NaN       3113209
# 1                      NaN       3113272
# 2                      NaN       3113548
# 3                      NaN       3113347
# 4                      NaN       3113131
# ...                    ...           ...
# 257374                 NaN       2768992
# 257375                 NaN       2768986
# 257376                 NaN       2768865
# 257377                 NaN       2768990
# 257378                 NaN       2768751
#
# [257379 rows x 12 columns]

# %%
complaints.columns
# Out:
# Index(['Date received', 'Company', 'State', 'ZIP code', 'Tags',
#        'Consumer consent provided?', 'Submitted via', 'Date sent to company',
#        'Company response to consumer', 'Timely response?',
#        'Consumer disputed?', 'Complaint ID'],
#       dtype='object')

# %%
complaints2 = pd.read_csv("Copy of Complaints csv.csv")
complaints2
# Out:
#        Date received                                            Product  \
# 0         12/31/2018                                    Debt collection
# 1         12/31/2018                        Credit card or prepaid card
# 2         12/31/2018  Credit reporting, credit repair services, or o...
# 3         12/31/2018  Credit reporting, credit repair services, or o...
# 4         12/31/2018                              Vehicle loan or lease
# ...              ...                                                ...
# 257374      1/1/2018                                    Debt collection
# 257375      1/1/2018  Credit reporting, credit repair services, or o...
# 257376      1/1/2018  Money transfer, virtual currency, or money ser...
# 257377      1/1/2018  Money transfer, virtual currency, or money ser...
# 257378      1/1/2018          Payday loan, title loan, or personal loan
#
#                                        Sub-product  \
# 0                                        Auto debt
# 1       General-purpose credit card or charge card
# 2                                 Credit reporting
# 3                                 Credit reporting
# 4                                            Lease
# ...                                            ...
# 257374                            Credit card debt
# 257375                            Credit reporting
# 257376                            Virtual currency
# 257377                   Foreign currency exchange
# 257378                                  Title loan
#
#                                                     Issue  \
# 0                       Attempts to collect debt not owed
# 1       Advertising and marketing, including promotion...
# 2                    Incorrect information on your report
# 3                    Incorrect information on your report
# 4                              Managing the loan or lease
# ...                                                   ...
# 257374  Took or threatened to take negative or legal a...
# 257375  Problem with a credit reporting company's inve...
# 257376              Money was not available when promised
# 257377                      Problem with customer service
# 257378         Charged fees or interest you didn't expect
#
#                                                 Sub-issue  \
# 0                       Debt was result of identity theft
# 1          Didn't receive advertised or promotional terms
# 2                     Information belongs to someone else
# 3                     Information belongs to someone else
# 4                               Problem with fees charged
# ...                                                   ...
# 257374  Threatened or suggested your credit would be d...
# 257375  Difficulty submitting a dispute or getting inf...
# 257376                                                NaN
# 257377                                                NaN
# 257378                                                NaN
#
#                              Consumer complaint narrative  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4       I have a Mercedes benz XXXX convertible. The c...
# ...                                                   ...
# 257374                                                NaN
# 257375  Dear XXXX, XXXX And Equifax, XXXX, I received ...
# 257376  I sold Bitcoin through Coinbase and their syst...
# 257377  Hi I have a account with coinbase and i hold f...
# 257378  ja m a Service Connected XXXX Veteran with XXX...
#
#                                   Company public response  \
# 0       Company has responded to the consumer and the ...
# 1                                                     NaN
# 2                                                     NaN
# 3       Company has responded to the consumer and the ...
# 4                                                     NaN
# ...                                                   ...
# 257374                                                NaN
# 257375                                                NaN
# 257376                                                NaN
# 257377                                                NaN
# 257378                                                NaN
#
#                                        Company  Complaint ID
# 0          Experian Information Solutions Inc.       3113209
# 1                         JPMORGAN CHASE & CO.       3113272
# 2                                EQUIFAX, INC.       3113548
# 3       TRANSUNION INTERMEDIATE HOLDINGS, INC.       3113347
# 4             MERCEDES BENZ FINANCIAL SERVICES       3113131
# ...                                        ...           ...
# 257374         Resurgent Capital Services L.P.       2768992
# 257375                           EQUIFAX, INC.       2768986
# 257376                          Coinbase, Inc.       2768865
# 257377                          Coinbase, Inc.       2768990
# 257378            WHEELS FINANCIAL GROUP, LLC.       2768751
#
# [257379 rows x 9 columns]

# %%
complaints['Complaint ID'] = complaints['Complaint ID'].astype(str)

# %%
complaints2['Complaint ID'] = complaints2['Complaint ID'].astype(str)

# %%
complaints["Company_ID"] = complaints["Company"] + "_" + complaints["Complaint ID"]
complaints
# Out:
#        Date received                                 Company State ZIP code  \
# 0         12/31/2018     Experian Information Solutions Inc.    TX    77072
# 1         12/31/2018                    JPMORGAN CHASE & CO.   NaN      NaN
# 2         12/31/2018                           EQUIFAX, INC.    FL    330XX
# 3         12/31/2018  TRANSUNION INTERMEDIATE HOLDINGS, INC.    GA    30342
# 4         12/31/2018        MERCEDES BENZ FINANCIAL SERVICES    CA      NaN
# ...              ...                                     ...   ...      ...
# 257374      1/1/2018         Resurgent Capital Services L.P.    IN    47714
# 257375      1/1/2018                           EQUIFAX, INC.    LA    703XX
# 257376      1/1/2018                          Coinbase, Inc.    NJ    074XX
# 257377      1/1/2018                          Coinbase, Inc.   NaN      NaN
# 257378      1/1/2018            WHEELS FINANCIAL GROUP, LLC.    PA      NaN
#
#                  Tags Consumer consent provided? Submitted via  \
# 0                 NaN       Consent not provided           Web
# 1                 NaN                        NaN         Phone
# 2                 NaN                      Other           Web
# 3                 NaN                        NaN      Referral
# 4                 NaN           Consent provided           Web
# ...               ...                        ...           ...
# 257374            NaN       Consent not provided           Web
# 257375            NaN           Consent provided           Web
# 257376            NaN           Consent provided           Web
# 257377            NaN           Consent provided           Web
# 257378  Servicemember           Consent provided           Web
#
#        Date sent to company Company response to consumer Timely response?  \
# 0                12/31/2018      Closed with explanation              Yes
# 1                  1/3/2019      Closed with explanation              Yes
# 2                12/31/2018      Closed with explanation              Yes
# 3                12/31/2018      Closed with explanation              Yes
# 4                12/31/2018      Closed with explanation              Yes
# ...                     ...                          ...              ...
# 257374             1/3/2018      Closed with explanation              Yes
# 257375             1/1/2018      Closed with explanation              Yes
# 257376             1/1/2018      Closed with explanation              Yes
# 257377             1/3/2018      Closed with explanation              Yes
# 257378            1/17/2018      Closed with explanation              Yes
#
#         Consumer disputed? Complaint ID  \
# 0                      NaN      3113209
# 1                      NaN      3113272
# 2                      NaN      3113548
# 3                      NaN      3113347
# 4                      NaN      3113131
# ...                    ...          ...
# 257374                 NaN      2768992
# 257375                 NaN      2768986
# 257376                 NaN      2768865
# 257377                 NaN      2768990
# 257378                 NaN      2768751
#
#                                             Company_ID
# 0          Experian Information Solutions Inc._3113209
# 1                         JPMORGAN CHASE & CO._3113272
# 2                                EQUIFAX, INC._3113548
# 3       TRANSUNION INTERMEDIATE HOLDINGS, INC._3113347
# 4             MERCEDES BENZ FINANCIAL SERVICES_3113131
# ...                                                ...
# 257374         Resurgent Capital Services L.P._2768992
# 257375                           EQUIFAX, INC._2768986
# 257376                          Coinbase, Inc._2768865
# 257377                          Coinbase, Inc._2768990
# 257378            WHEELS FINANCIAL GROUP, LLC._2768751
#
# [257379 rows x 13 columns]

# %%
complaints2["Company_ID"] = complaints2["Company"] + "_" + complaints2["Complaint ID"]
complaints2
# Out:
#        Date received                                            Product  \
# 0         12/31/2018                                    Debt collection
# 1         12/31/2018                        Credit card or prepaid card
# 2         12/31/2018  Credit reporting, credit repair services, or o...
# 3         12/31/2018  Credit reporting, credit repair services, or o...
# 4         12/31/2018                              Vehicle loan or lease
# ...              ...                                                ...
# 257374      1/1/2018                                    Debt collection
# 257375      1/1/2018  Credit reporting, credit repair services, or o...
# 257376      1/1/2018  Money transfer, virtual currency, or money ser...
# 257377      1/1/2018  Money transfer, virtual currency, or money ser...
# 257378      1/1/2018          Payday loan, title loan, or personal loan
#
#                                        Sub-product  \
# 0                                        Auto debt
# 1       General-purpose credit card or charge card
# 2                                 Credit reporting
# 3                                 Credit reporting
# 4                                            Lease
# ...                                            ...
# 257374                            Credit card debt
# 257375                            Credit reporting
# 257376                            Virtual currency
# 257377                   Foreign currency exchange
# 257378                                  Title loan
#
#                                                     Issue  \
# 0                       Attempts to collect debt not owed
# 1       Advertising and marketing, including promotion...
# 2                    Incorrect information on your report
# 3                    Incorrect information on your report
# 4                              Managing the loan or lease
# ...                                                   ...
# 257374  Took or threatened to take negative or legal a...
# 257375  Problem with a credit reporting company's inve...
# 257376              Money was not available when promised
# 257377                      Problem with customer service
# 257378         Charged fees or interest you didn't expect
#
#                                                 Sub-issue  \
# 0                       Debt was result of identity theft
# 1          Didn't receive advertised or promotional terms
# 2                     Information belongs to someone else
# 3                     Information belongs to someone else
# 4                               Problem with fees charged
# ...                                                   ...
# 257374  Threatened or suggested your credit would be d...
# 257375  Difficulty submitting a dispute or getting inf...
# 257376                                                NaN
# 257377                                                NaN
# 257378                                                NaN
#
#                              Consumer complaint narrative  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4       I have a Mercedes benz XXXX convertible. The c...
# ...                                                   ...
# 257374                                                NaN
# 257375  Dear XXXX, XXXX And Equifax, XXXX, I received ...
# 257376  I sold Bitcoin through Coinbase and their syst...
# 257377  Hi I have a account with coinbase and i hold f...
# 257378  ja m a Service Connected XXXX Veteran with XXX...
#
#                                   Company public response  \
# 0       Company has responded to the consumer and the ...
# 1                                                     NaN
# 2                                                     NaN
# 3       Company has responded to the consumer and the ...
# 4                                                     NaN
# ...                                                   ...
# 257374                                                NaN
# 257375                                                NaN
# 257376                                                NaN
# 257377                                                NaN
# 257378                                                NaN
#
#                                        Company Complaint ID  \
# 0          Experian Information Solutions Inc.      3113209
# 1                         JPMORGAN CHASE & CO.      3113272
# 2                                EQUIFAX, INC.      3113548
# 3       TRANSUNION INTERMEDIATE HOLDINGS, INC.      3113347
# 4             MERCEDES BENZ FINANCIAL SERVICES      3113131
# ...                                        ...          ...
# 257374         Resurgent Capital Services L.P.      2768992
# 257375                           EQUIFAX, INC.      2768986
# 257376                          Coinbase, Inc.      2768865
# 257377                          Coinbase, Inc.      2768990
# 257378            WHEELS FINANCIAL GROUP, LLC.      2768751
#
#                                             Company_ID
# 0          Experian Information Solutions Inc._3113209
# 1                         JPMORGAN CHASE & CO._3113272
# 2                                EQUIFAX, INC._3113548
# 3       TRANSUNION INTERMEDIATE HOLDINGS, INC._3113347
# 4             MERCEDES BENZ FINANCIAL SERVICES_3113131
# ...                                                ...
# 257374         Resurgent Capital Services L.P._2768992
# 257375                           EQUIFAX, INC._2768986
# 257376                          Coinbase, Inc._2768865
# 257377                          Coinbase, Inc._2768990
# 257378            WHEELS FINANCIAL GROUP, LLC._2768751
#
# [257379 rows x 10 columns]

# %%
complaints.head()
# Out:
#   Date received                                 Company State ZIP code Tags  \
# 0    12/31/2018     Experian Information Solutions Inc.    TX    77072  NaN
# 1    12/31/2018                    JPMORGAN CHASE & CO.   NaN      NaN  NaN
# 2    12/31/2018                           EQUIFAX, INC.    FL    330XX  NaN
# 3    12/31/2018  TRANSUNION INTERMEDIATE HOLDINGS, INC.    GA    30342  NaN
# 4    12/31/2018        MERCEDES BENZ FINANCIAL SERVICES    CA      NaN  NaN
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0       Consent not provided           Web           12/31/2018
# 1                        NaN         Phone             1/3/2019
# 2                      Other           Web           12/31/2018
# 3                        NaN      Referral           12/31/2018
# 4           Consent provided           Web           12/31/2018
#
#   Company response to consumer Timely response?  Consumer disputed?  \
# 0      Closed with explanation              Yes                 NaN
# 1      Closed with explanation              Yes                 NaN
# 2      Closed with explanation              Yes                 NaN
# 3      Closed with explanation              Yes                 NaN
# 4      Closed with explanation              Yes                 NaN
#
#   Complaint ID                                      Company_ID
# 0      3113209     Experian Information Solutions Inc._3113209
# 1      3113272                    JPMORGAN CHASE & CO._3113272
# 2      3113548                           EQUIFAX, INC._3113548
# 3      3113347  TRANSUNION INTERMEDIATE HOLDINGS, INC._3113347
# 4      3113131        MERCEDES BENZ FINANCIAL SERVICES_3113131

# %%
all_complaints = pd.merge(complaints2, complaints, how="left", on="Company_ID")
all_complaints
# Out:
#        Date received_x                                            Product  \
# 0           12/31/2018                                    Debt collection
# 1           12/31/2018                        Credit card or prepaid card
# 2           12/31/2018  Credit reporting, credit repair services, or o...
# 3           12/31/2018  Credit reporting, credit repair services, or o...
# 4           12/31/2018                              Vehicle loan or lease
# ...                ...                                                ...
# 257374        1/1/2018                                    Debt collection
# 257375        1/1/2018  Credit reporting, credit repair services, or o...
# 257376        1/1/2018  Money transfer, virtual currency, or money ser...
# 257377        1/1/2018  Money transfer, virtual currency, or money ser...
# 257378        1/1/2018          Payday loan, title loan, or personal loan
#
#                                        Sub-product  \
# 0                                        Auto debt
# 1       General-purpose credit card or charge card
# 2                                 Credit reporting
# 3                                 Credit reporting
# 4                                            Lease
# ...                                            ...
# 257374                            Credit card debt
# 257375                            Credit reporting
# 257376                            Virtual currency
# 257377                   Foreign currency exchange
# 257378                                  Title loan
#
#                                                     Issue  \
# 0                       Attempts to collect debt not owed
# 1       Advertising and marketing, including promotion...
# 2                    Incorrect information on your report
# 3                    Incorrect information on your report
# 4                              Managing the loan or lease
# ...                                                   ...
# 257374  Took or threatened to take negative or legal a...
# 257375  Problem with a credit reporting company's inve...
# 257376              Money was not available when promised
# 257377                      Problem with customer service
# 257378         Charged fees or interest you didn't expect
#
#                                                 Sub-issue  \
# 0                       Debt was result of identity theft
# 1          Didn't receive advertised or promotional terms
# 2                     Information belongs to someone else
# 3                     Information belongs to someone else
# 4                               Problem with fees charged
# ...                                                   ...
# 257374  Threatened or suggested your credit would be d...
# 257375  Difficulty submitting a dispute or getting inf...
# 257376                                                NaN
# 257377                                                NaN
# 257378                                                NaN
#
#                              Consumer complaint narrative  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4       I have a Mercedes benz XXXX convertible. The c...
# ...                                                   ...
# 257374                                                NaN
# 257375  Dear XXXX, XXXX And Equifax, XXXX, I received ...
# 257376  I sold Bitcoin through Coinbase and their syst...
# 257377  Hi I have a account with coinbase and i hold f...
# 257378  ja m a Service Connected XXXX Veteran with XXX...
#
#                                   Company public response  \
# 0       Company has responded to the consumer and the ...
# 1                                                     NaN
# 2                                                     NaN
# 3       Company has responded to the consumer and the ...
# 4                                                     NaN
# ...                                                   ...
# 257374                                                NaN
# 257375                                                NaN
# 257376                                                NaN
# 257377                                                NaN
# 257378                                                NaN
#
#                                      Company_x Complaint ID_x  \
# 0          Experian Information Solutions Inc.        3113209
# 1                         JPMORGAN CHASE & CO.        3113272
# 2                                EQUIFAX, INC.        3113548
# 3       TRANSUNION INTERMEDIATE HOLDINGS, INC.        3113347
# 4             MERCEDES BENZ FINANCIAL SERVICES        3113131
# ...                                        ...            ...
# 257374         Resurgent Capital Services L.P.        2768992
# 257375                           EQUIFAX, INC.        2768986
# 257376                          Coinbase, Inc.        2768865
# 257377                          Coinbase, Inc.        2768990
# 257378            WHEELS FINANCIAL GROUP, LLC.        2768751
#
#                                             Company_ID  ... State ZIP code  \
# 0          Experian Information Solutions Inc._3113209  ...    TX    77072
# 1                         JPMORGAN CHASE & CO._3113272  ...   NaN      NaN
# 2                                EQUIFAX, INC._3113548  ...    FL    330XX
# 3       TRANSUNION INTERMEDIATE HOLDINGS, INC._3113347  ...    GA    30342
# 4             MERCEDES BENZ FINANCIAL SERVICES_3113131  ...    CA      NaN
# ...                                                ...  ...   ...      ...
# 257374         Resurgent Capital Services L.P._2768992  ...    IN    47714
# 257375                           EQUIFAX, INC._2768986  ...    LA    703XX
# 257376                          Coinbase, Inc._2768865  ...    NJ    074XX
# 257377                          Coinbase, Inc._2768990  ...   NaN      NaN
# 257378            WHEELS FINANCIAL GROUP, LLC._2768751  ...    PA      NaN
#
#                  Tags Consumer consent provided? Submitted via  \
# 0                 NaN       Consent not provided           Web
# 1                 NaN                        NaN         Phone
# 2                 NaN                      Other           Web
# 3                 NaN                        NaN      Referral
# 4                 NaN           Consent provided           Web
# ...               ...                        ...           ...
# 257374            NaN       Consent not provided           Web
# 257375            NaN           Consent provided           Web
# 257376            NaN           Consent provided           Web
# 257377            NaN           Consent provided           Web
# 257378  Servicemember           Consent provided           Web
#
#        Date sent to company Company response to consumer Timely response?  \
# 0                12/31/2018      Closed with explanation              Yes
# 1                  1/3/2019      Closed with explanation              Yes
# 2                12/31/2018      Closed with explanation              Yes
# 3                12/31/2018      Closed with explanation              Yes
# 4                12/31/2018      Closed with explanation              Yes
# ...                     ...                          ...              ...
# 257374             1/3/2018      Closed with explanation              Yes
# 257375             1/1/2018      Closed with explanation              Yes
# 257376             1/1/2018      Closed with explanation              Yes
# 257377             1/3/2018      Closed with explanation              Yes
# 257378            1/17/2018      Closed with explanation              Yes
#
#        Consumer disputed? Complaint ID_y
# 0                     NaN        3113209
# 1                     NaN        3113272
# 2                     NaN        3113548
# 3                     NaN        3113347
# 4                     NaN        3113131
# ...                   ...            ...
# 257374                NaN        2768992
# 257375                NaN        2768986
# 257376                NaN        2768865
# 257377                NaN        2768990
# 257378                NaN        2768751
#
# [257379 rows x 22 columns]

# %%
most_complaints_by_product = pd.DataFrame(all_complaints["Product"].value_counts().reset_index())
most_complaints_by_product
# Out:
#                                              Product   count
# 0  Credit reporting, credit repair services, or o...  111642
# 1                                    Debt collection   51211
# 2                                           Mortgage   24580
# 3                        Credit card or prepaid card   24251
# 4                        Checking or savings account   21212
# 5                                       Student loan    8781
# 6                              Vehicle loan or lease    5894
# 7  Money transfer, virtual currency, or money ser...    5435
# 8          Payday loan, title loan, or personal loan    4373

# %%
import matplotlib.pyplot as plt

# %%
plt.barh(most_complaints_by_product["Product"],most_complaints_by_product["count"])
plt.title("Number of Complaints by Product")
# Out:
# Text(0.5, 1.0, 'Number of Complaints by Product')

# %%
# It appears that the number of complaints was the highest for Credit reporting, credit repair services, or other personal consumer reports.

# %%
all_complaints["Date received_x"] = pd.to_datetime(all_complaints["Date received_x"])
all_complaints
# Out:
#        Date received_x                                            Product  \
# 0           2018-12-31                                    Debt collection
# 1           2018-12-31                        Credit card or prepaid card
# 2           2018-12-31  Credit reporting, credit repair services, or o...
# 3           2018-12-31  Credit reporting, credit repair services, or o...
# 4           2018-12-31                              Vehicle loan or lease
# ...                ...                                                ...
# 257374      2018-01-01                                    Debt collection
# 257375      2018-01-01  Credit reporting, credit repair services, or o...
# 257376      2018-01-01  Money transfer, virtual currency, or money ser...
# 257377      2018-01-01  Money transfer, virtual currency, or money ser...
# 257378      2018-01-01          Payday loan, title loan, or personal loan
#
#                                        Sub-product  \
# 0                                        Auto debt
# 1       General-purpose credit card or charge card
# 2                                 Credit reporting
# 3                                 Credit reporting
# 4                                            Lease
# ...                                            ...
# 257374                            Credit card debt
# 257375                            Credit reporting
# 257376                            Virtual currency
# 257377                   Foreign currency exchange
# 257378                                  Title loan
#
#                                                     Issue  \
# 0                       Attempts to collect debt not owed
# 1       Advertising and marketing, including promotion...
# 2                    Incorrect information on your report
# 3                    Incorrect information on your report
# 4                              Managing the loan or lease
# ...                                                   ...
# 257374  Took or threatened to take negative or legal a...
# 257375  Problem with a credit reporting company's inve...
# 257376              Money was not available when promised
# 257377                      Problem with customer service
# 257378         Charged fees or interest you didn't expect
#
#                                                 Sub-issue  \
# 0                       Debt was result of identity theft
# 1          Didn't receive advertised or promotional terms
# 2                     Information belongs to someone else
# 3                     Information belongs to someone else
# 4                               Problem with fees charged
# ...                                                   ...
# 257374  Threatened or suggested your credit would be d...
# 257375  Difficulty submitting a dispute or getting inf...
# 257376                                                NaN
# 257377                                                NaN
# 257378                                                NaN
#
#                              Consumer complaint narrative  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4       I have a Mercedes benz XXXX convertible. The c...
# ...                                                   ...
# 257374                                                NaN
# 257375  Dear XXXX, XXXX And Equifax, XXXX, I received ...
# 257376  I sold Bitcoin through Coinbase and their syst...
# 257377  Hi I have a account with coinbase and i hold f...
# 257378  ja m a Service Connected XXXX Veteran with XXX...
#
#                                   Company public response  \
# 0       Company has responded to the consumer and the ...
# 1                                                     NaN
# 2                                                     NaN
# 3       Company has responded to the consumer and the ...
# 4                                                     NaN
# ...                                                   ...
# 257374                                                NaN
# 257375                                                NaN
# 257376                                                NaN
# 257377                                                NaN
# 257378                                                NaN
#
#                                      Company_x Complaint ID_x  \
# 0          Experian Information Solutions Inc.        3113209
# 1                         JPMORGAN CHASE & CO.        3113272
# 2                                EQUIFAX, INC.        3113548
# 3       TRANSUNION INTERMEDIATE HOLDINGS, INC.        3113347
# 4             MERCEDES BENZ FINANCIAL SERVICES        3113131
# ...                                        ...            ...
# 257374         Resurgent Capital Services L.P.        2768992
# 257375                           EQUIFAX, INC.        2768986
# 257376                          Coinbase, Inc.        2768865
# 257377                          Coinbase, Inc.        2768990
# 257378            WHEELS FINANCIAL GROUP, LLC.        2768751
#
#                                             Company_ID  ... State ZIP code  \
# 0          Experian Information Solutions Inc._3113209  ...    TX    77072
# 1                         JPMORGAN CHASE & CO._3113272  ...   NaN      NaN
# 2                                EQUIFAX, INC._3113548  ...    FL    330XX
# 3       TRANSUNION INTERMEDIATE HOLDINGS, INC._3113347  ...    GA    30342
# 4             MERCEDES BENZ FINANCIAL SERVICES_3113131  ...    CA      NaN
# ...                                                ...  ...   ...      ...
# 257374         Resurgent Capital Services L.P._2768992  ...    IN    47714
# 257375                           EQUIFAX, INC._2768986  ...    LA    703XX
# 257376                          Coinbase, Inc._2768865  ...    NJ    074XX
# 257377                          Coinbase, Inc._2768990  ...   NaN      NaN
# 257378            WHEELS FINANCIAL GROUP, LLC._2768751  ...    PA      NaN
#
#                  Tags Consumer consent provided? Submitted via  \
# 0                 NaN       Consent not provided           Web
# 1                 NaN                        NaN         Phone
# 2                 NaN                      Other           Web
# 3                 NaN                        NaN      Referral
# 4                 NaN           Consent provided           Web
# ...               ...                        ...           ...
# 257374            NaN       Consent not provided           Web
# 257375            NaN           Consent provided           Web
# 257376            NaN           Consent provided           Web
# 257377            NaN           Consent provided           Web
# 257378  Servicemember           Consent provided           Web
#
#        Date sent to company Company response to consumer Timely response?  \
# 0                12/31/2018      Closed with explanation              Yes
# 1                  1/3/2019      Closed with explanation              Yes
# 2                12/31/2018      Closed with explanation              Yes
# 3                12/31/2018      Closed with explanation              Yes
# 4                12/31/2018      Closed with explanation              Yes
# ...                     ...                          ...              ...
# 257374             1/3/2018      Closed with explanation              Yes
# 257375             1/1/2018      Closed with explanation              Yes
# 257376             1/1/2018      Closed with explanation              Yes
# 257377             1/3/2018      Closed with explanation              Yes
# 257378            1/17/2018      Closed with explanation              Yes
#
#        Consumer disputed? Complaint ID_y
# 0                     NaN        3113209
# 1                     NaN        3113272
# 2                     NaN        3113548
# 3                     NaN        3113347
# 4                     NaN        3113131
# ...                   ...            ...
# 257374                NaN        2768992
# 257375                NaN        2768986
# 257376                NaN        2768865
# 257377                NaN        2768990
# 257378                NaN        2768751
#
# [257379 rows x 22 columns]

# %%
num_complaints_by_date = pd.DataFrame(all_complaints.groupby("Date received_x")["Complaint ID_x"].count().reset_index())
num_complaints_by_date
# Out:
#     Date received_x  Complaint ID_x
# 0        2018-01-01             271
# 1        2018-01-02             740
# 2        2018-01-03             990
# 3        2018-01-04             896
# 4        2018-01-05             831
# ..              ...             ...
# 360      2018-12-27             907
# 361      2018-12-28             723
# 362      2018-12-29             378
# 363      2018-12-30             239
# 364      2018-12-31             513
#
# [365 rows x 2 columns]

# %%
plt.figure(figsize=(20, 6))
plt.plot(num_complaints_by_date["Date received_x"],num_complaints_by_date["Complaint ID_x"])
plt.title("Number of Complaints by Date")
# Out:
# Text(0.5, 1.0, 'Number of Complaints by Date')

# %%
product_responses = pd.DataFrame(all_complaints.groupby("Product")["Timely response?"].value_counts().reset_index())
product_responses
# Out:
#                                               Product Timely response?   count
# 0                         Checking or savings account              Yes   21069
# 1                         Checking or savings account               No     143
# 2                         Credit card or prepaid card              Yes   24113
# 3                         Credit card or prepaid card               No     138
# 4   Credit reporting, credit repair services, or o...              Yes  110839
# 5   Credit reporting, credit repair services, or o...               No     803
# 6                                     Debt collection              Yes   48812
# 7                                     Debt collection               No    2399
# 8   Money transfer, virtual currency, or money ser...              Yes    5340
# 9   Money transfer, virtual currency, or money ser...               No      95
# 10                                           Mortgage              Yes   24185
# 11                                           Mortgage               No     395
# 12          Payday loan, title loan, or personal loan              Yes    4111
# 13          Payday loan, title loan, or personal loan               No     262
# 14                                       Student loan              Yes    8582
# 15                                       Student loan               No     199
# 16                              Vehicle loan or lease              Yes    5677
# 17                              Vehicle loan or lease               No     217

# %%
product_responses_yes = product_responses[product_responses["Timely response?"] == "Yes"]
product_responses_yes
# Out:
#                                               Product Timely response?   count
# 0                         Checking or savings account              Yes   21069
# 2                         Credit card or prepaid card              Yes   24113
# 4   Credit reporting, credit repair services, or o...              Yes  110839
# 6                                     Debt collection              Yes   48812
# 8   Money transfer, virtual currency, or money ser...              Yes    5340
# 10                                           Mortgage              Yes   24185
# 12          Payday loan, title loan, or personal loan              Yes    4111
# 14                                       Student loan              Yes    8582
# 16                              Vehicle loan or lease              Yes    5677

# %%
product_responses_no = product_responses[product_responses["Timely response?"] == "No"]
product_responses_no
# Out:
#                                               Product Timely response?  count
# 1                         Checking or savings account               No    143
# 3                         Credit card or prepaid card               No    138
# 5   Credit reporting, credit repair services, or o...               No    803
# 7                                     Debt collection               No   2399
# 9   Money transfer, virtual currency, or money ser...               No     95
# 11                                           Mortgage               No    395
# 13          Payday loan, title loan, or personal loan               No    262
# 15                                       Student loan               No    199
# 17                              Vehicle loan or lease               No    217

# %%
import numpy as np

# %%
plt.barh(product_responses_yes["Product"], product_responses_yes["count"], label = 'Yes') 

plt.title("Number of Timely Responses per Product")
# Out:
# Text(0.5, 1.0, 'Number of Timely Responses per Product')

# %%
# It appears that the credit reporting has the most timely responses all of the other Products.
