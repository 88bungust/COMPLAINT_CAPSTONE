# %%
import pandas as pd

# %%
complaints = pd.read_csv("COMPLAINTS SHEET 2.csv")
complaints
# Out:
#        Date received                                 Company  \
# 0           1/1/2018                  Messerli & Kramer P.A.
# 1           1/1/2018                           EQUIFAX, INC.
# 2           1/1/2018       CAPITAL ONE FINANCIAL CORPORATION
# 3           1/1/2018                   WELLS FARGO & COMPANY
# 4           1/1/2018  TRANSUNION INTERMEDIATE HOLDINGS, INC.
# ...              ...                                     ...
# 257374           NaN                                     NaN
# 257375           NaN                                     NaN
# 257376           NaN                                     NaN
# 257377           NaN                                     NaN
# 257378           NaN                                     NaN
#
#        Date sent to company Company response to consumer Timely response?  \
# 0                  1/1/2018      Closed with explanation              Yes
# 1                  1/1/2018      Closed with explanation              Yes
# 2                  1/1/2018      Closed with explanation              Yes
# 3                  1/1/2018      Closed with explanation              Yes
# 4                  1/1/2018      Closed with explanation              Yes
# ...                     ...                          ...              ...
# 257374                  NaN                          NaN              NaN
# 257375                  NaN                          NaN              NaN
# 257376                  NaN                          NaN              NaN
# 257377                  NaN                          NaN              NaN
# 257378                  NaN                          NaN              NaN
#
#         Consumer disputed?  Complaint ID
# 0                      NaN     2768809.0
# 1                      NaN     2768922.0
# 2                      NaN     2768940.0
# 3                      NaN     2768821.0
# 4                      NaN     2768974.0
# ...                    ...           ...
# 257374                 NaN           NaN
# 257375                 NaN           NaN
# 257376                 NaN           NaN
# 257377                 NaN           NaN
# 257378                 NaN           NaN
#
# [257379 rows x 7 columns]

# %%
complaints = complaints[complaints["Date received"].notna()]
complaints
# Out:
#        Date received                                 Company  \
# 0           1/1/2018                  Messerli & Kramer P.A.
# 1           1/1/2018                           EQUIFAX, INC.
# 2           1/1/2018       CAPITAL ONE FINANCIAL CORPORATION
# 3           1/1/2018                   WELLS FARGO & COMPANY
# 4           1/1/2018  TRANSUNION INTERMEDIATE HOLDINGS, INC.
# ...              ...                                     ...
# 136070     6/30/2018            National Credit Systems,Inc.
# 136071     6/30/2018                    JPMORGAN CHASE & CO.
# 136072     6/30/2018                   WELLS FARGO & COMPANY
# 136073     6/30/2018                          Coinbase, Inc.
# 136074     6/30/2018                           EQUIFAX, INC.
#
#        Date sent to company Company response to consumer Timely response?  \
# 0                  1/1/2018      Closed with explanation              Yes
# 1                  1/1/2018      Closed with explanation              Yes
# 2                  1/1/2018      Closed with explanation              Yes
# 3                  1/1/2018      Closed with explanation              Yes
# 4                  1/1/2018      Closed with explanation              Yes
# ...                     ...                          ...              ...
# 136070            6/30/2018      Closed with explanation              Yes
# 136071            6/30/2018      Closed with explanation              Yes
# 136072            6/30/2018      Closed with explanation              Yes
# 136073            6/30/2018      Closed with explanation              Yes
# 136074            6/30/2018      Closed with explanation              Yes
#
#         Consumer disputed?  Complaint ID
# 0                      NaN     2768809.0
# 1                      NaN     2768922.0
# 2                      NaN     2768940.0
# 3                      NaN     2768821.0
# 4                      NaN     2768974.0
# ...                    ...           ...
# 136070                 NaN     2949947.0
# 136071                 NaN     2950380.0
# 136072                 NaN     2950472.0
# 136073                 NaN     2950381.0
# 136074                 NaN     2950356.0
#
# [136075 rows x 7 columns]

# %%
complaints.columns
# Out:
# Index(['Date received', 'Company', 'Date sent to company',
#        'Company response to consumer', 'Timely response?',
#        'Consumer disputed?', 'Complaint ID'],
#       dtype='object')

# %%
complaints2 = pd.read_csv("Copy of Complaints csv.csv")
complaints2
# Out:
#        Date received                                            Product  \
# 0           1/1/2018                                    Debt collection
# 1           1/1/2018  Credit reporting, credit repair services, or o...
# 2           1/1/2018                        Credit card or prepaid card
# 3           1/1/2018  Credit reporting, credit repair services, or o...
# 4           1/1/2018  Credit reporting, credit repair services, or o...
# ...              ...                                                ...
# 136070     6/30/2018                                    Debt collection
# 136071     6/30/2018                        Credit card or prepaid card
# 136072     6/30/2018                        Checking or savings account
# 136073     6/30/2018  Money transfer, virtual currency, or money ser...
# 136074     6/30/2018                                    Debt collection
#
#                                        Company  Complaint ID
# 0                       Messerli & Kramer P.A.       2768809
# 1                                EQUIFAX, INC.       2768922
# 2            CAPITAL ONE FINANCIAL CORPORATION       2768940
# 3                        WELLS FARGO & COMPANY       2768821
# 4       TRANSUNION INTERMEDIATE HOLDINGS, INC.       2768974
# ...                                        ...           ...
# 136070            National Credit Systems,Inc.       2949947
# 136071                    JPMORGAN CHASE & CO.       2950380
# 136072                   WELLS FARGO & COMPANY       2950472
# 136073                          Coinbase, Inc.       2950381
# 136074                           EQUIFAX, INC.       2950356
#
# [136075 rows x 4 columns]

# %%
complaints['Complaint ID'] = complaints['Complaint ID'].astype(int).astype(str)
# Out:
# C:\Users\bungu\AppData\Local\Temp\ipykernel_12052\3011223987.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   complaints['Complaint ID'] = complaints['Complaint ID'].astype(int).astype(str)

# %%
complaints2['Complaint ID'] = complaints2['Complaint ID'].astype(int).astype(str)

# %%
complaints["Company_ID"] = complaints["Company"] + "_" + complaints["Complaint ID"]
complaints
# Out:
# C:\Users\bungu\AppData\Local\Temp\ipykernel_12052\4242741371.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   complaints["Company_ID"] = complaints["Company"] + "_" + complaints["Complaint ID"]
#        Date received                                 Company  \
# 0           1/1/2018                  Messerli & Kramer P.A.
# 1           1/1/2018                           EQUIFAX, INC.
# 2           1/1/2018       CAPITAL ONE FINANCIAL CORPORATION
# 3           1/1/2018                   WELLS FARGO & COMPANY
# 4           1/1/2018  TRANSUNION INTERMEDIATE HOLDINGS, INC.
# ...              ...                                     ...
# 136070     6/30/2018            National Credit Systems,Inc.
# 136071     6/30/2018                    JPMORGAN CHASE & CO.
# 136072     6/30/2018                   WELLS FARGO & COMPANY
# 136073     6/30/2018                          Coinbase, Inc.
# 136074     6/30/2018                           EQUIFAX, INC.
#
#        Date sent to company Company response to consumer Timely response?  \
# 0                  1/1/2018      Closed with explanation              Yes
# 1                  1/1/2018      Closed with explanation              Yes
# 2                  1/1/2018      Closed with explanation              Yes
# 3                  1/1/2018      Closed with explanation              Yes
# 4                  1/1/2018      Closed with explanation              Yes
# ...                     ...                          ...              ...
# 136070            6/30/2018      Closed with explanation              Yes
# 136071            6/30/2018      Closed with explanation              Yes
# 136072            6/30/2018      Closed with explanation              Yes
# 136073            6/30/2018      Closed with explanation              Yes
# 136074            6/30/2018      Closed with explanation              Yes
#
#         Consumer disputed? Complaint ID  \
# 0                      NaN      2768809
# 1                      NaN      2768922
# 2                      NaN      2768940
# 3                      NaN      2768821
# 4                      NaN      2768974
# ...                    ...          ...
# 136070                 NaN      2949947
# 136071                 NaN      2950380
# 136072                 NaN      2950472
# 136073                 NaN      2950381
# 136074                 NaN      2950356
#
#                                             Company_ID
# 0                       Messerli & Kramer P.A._2768809
# 1                                EQUIFAX, INC._2768922
# 2            CAPITAL ONE FINANCIAL CORPORATION_2768940
# 3                        WELLS FARGO & COMPANY_2768821
# 4       TRANSUNION INTERMEDIATE HOLDINGS, INC._2768974
# ...                                                ...
# 136070            National Credit Systems,Inc._2949947
# 136071                    JPMORGAN CHASE & CO._2950380
# 136072                   WELLS FARGO & COMPANY_2950472
# 136073                          Coinbase, Inc._2950381
# 136074                           EQUIFAX, INC._2950356
#
# [136075 rows x 8 columns]

# %%
complaints2["Company_ID"] = complaints2["Company"] + "_" + complaints2["Complaint ID"]
complaints2
# Out:
#        Date received                                            Product  \
# 0           1/1/2018                                    Debt collection
# 1           1/1/2018  Credit reporting, credit repair services, or o...
# 2           1/1/2018                        Credit card or prepaid card
# 3           1/1/2018  Credit reporting, credit repair services, or o...
# 4           1/1/2018  Credit reporting, credit repair services, or o...
# ...              ...                                                ...
# 136070     6/30/2018                                    Debt collection
# 136071     6/30/2018                        Credit card or prepaid card
# 136072     6/30/2018                        Checking or savings account
# 136073     6/30/2018  Money transfer, virtual currency, or money ser...
# 136074     6/30/2018                                    Debt collection
#
#                                        Company Complaint ID  \
# 0                       Messerli & Kramer P.A.      2768809
# 1                                EQUIFAX, INC.      2768922
# 2            CAPITAL ONE FINANCIAL CORPORATION      2768940
# 3                        WELLS FARGO & COMPANY      2768821
# 4       TRANSUNION INTERMEDIATE HOLDINGS, INC.      2768974
# ...                                        ...          ...
# 136070            National Credit Systems,Inc.      2949947
# 136071                    JPMORGAN CHASE & CO.      2950380
# 136072                   WELLS FARGO & COMPANY      2950472
# 136073                          Coinbase, Inc.      2950381
# 136074                           EQUIFAX, INC.      2950356
#
#                                             Company_ID
# 0                       Messerli & Kramer P.A._2768809
# 1                                EQUIFAX, INC._2768922
# 2            CAPITAL ONE FINANCIAL CORPORATION_2768940
# 3                        WELLS FARGO & COMPANY_2768821
# 4       TRANSUNION INTERMEDIATE HOLDINGS, INC._2768974
# ...                                                ...
# 136070            National Credit Systems,Inc._2949947
# 136071                    JPMORGAN CHASE & CO._2950380
# 136072                   WELLS FARGO & COMPANY_2950472
# 136073                          Coinbase, Inc._2950381
# 136074                           EQUIFAX, INC._2950356
#
# [136075 rows x 5 columns]

# %%
complaints.head()
# Out:
#   Date received                                 Company Date sent to company  \
# 0      1/1/2018                  Messerli & Kramer P.A.             1/1/2018
# 1      1/1/2018                           EQUIFAX, INC.             1/1/2018
# 2      1/1/2018       CAPITAL ONE FINANCIAL CORPORATION             1/1/2018
# 3      1/1/2018                   WELLS FARGO & COMPANY             1/1/2018
# 4      1/1/2018  TRANSUNION INTERMEDIATE HOLDINGS, INC.             1/1/2018
#
#   Company response to consumer Timely response?  Consumer disputed?  \
# 0      Closed with explanation              Yes                 NaN
# 1      Closed with explanation              Yes                 NaN
# 2      Closed with explanation              Yes                 NaN
# 3      Closed with explanation              Yes                 NaN
# 4      Closed with explanation              Yes                 NaN
#
#   Complaint ID                                      Company_ID
# 0      2768809                  Messerli & Kramer P.A._2768809
# 1      2768922                           EQUIFAX, INC._2768922
# 2      2768940       CAPITAL ONE FINANCIAL CORPORATION_2768940
# 3      2768821                   WELLS FARGO & COMPANY_2768821
# 4      2768974  TRANSUNION INTERMEDIATE HOLDINGS, INC._2768974

# %%
all_complaints = pd.merge(complaints2, complaints, how="left", on="Company_ID")
all_complaints
# Out:
#        Date received_x                                            Product  \
# 0             1/1/2018                                    Debt collection
# 1             1/1/2018  Credit reporting, credit repair services, or o...
# 2             1/1/2018                        Credit card or prepaid card
# 3             1/1/2018  Credit reporting, credit repair services, or o...
# 4             1/1/2018  Credit reporting, credit repair services, or o...
# ...                ...                                                ...
# 136070       6/30/2018                                    Debt collection
# 136071       6/30/2018                        Credit card or prepaid card
# 136072       6/30/2018                        Checking or savings account
# 136073       6/30/2018  Money transfer, virtual currency, or money ser...
# 136074       6/30/2018                                    Debt collection
#
#                                      Company_x Complaint ID_x  \
# 0                       Messerli & Kramer P.A.        2768809
# 1                                EQUIFAX, INC.        2768922
# 2            CAPITAL ONE FINANCIAL CORPORATION        2768940
# 3                        WELLS FARGO & COMPANY        2768821
# 4       TRANSUNION INTERMEDIATE HOLDINGS, INC.        2768974
# ...                                        ...            ...
# 136070            National Credit Systems,Inc.        2949947
# 136071                    JPMORGAN CHASE & CO.        2950380
# 136072                   WELLS FARGO & COMPANY        2950472
# 136073                          Coinbase, Inc.        2950381
# 136074                           EQUIFAX, INC.        2950356
#
#                                             Company_ID Date received_y  \
# 0                       Messerli & Kramer P.A._2768809        1/1/2018
# 1                                EQUIFAX, INC._2768922        1/1/2018
# 2            CAPITAL ONE FINANCIAL CORPORATION_2768940        1/1/2018
# 3                        WELLS FARGO & COMPANY_2768821        1/1/2018
# 4       TRANSUNION INTERMEDIATE HOLDINGS, INC._2768974        1/1/2018
# ...                                                ...             ...
# 136070            National Credit Systems,Inc._2949947       6/30/2018
# 136071                    JPMORGAN CHASE & CO._2950380       6/30/2018
# 136072                   WELLS FARGO & COMPANY_2950472       6/30/2018
# 136073                          Coinbase, Inc._2950381       6/30/2018
# 136074                           EQUIFAX, INC._2950356       6/30/2018
#
#                                      Company_y Date sent to company  \
# 0                       Messerli & Kramer P.A.             1/1/2018
# 1                                EQUIFAX, INC.             1/1/2018
# 2            CAPITAL ONE FINANCIAL CORPORATION             1/1/2018
# 3                        WELLS FARGO & COMPANY             1/1/2018
# 4       TRANSUNION INTERMEDIATE HOLDINGS, INC.             1/1/2018
# ...                                        ...                  ...
# 136070            National Credit Systems,Inc.            6/30/2018
# 136071                    JPMORGAN CHASE & CO.            6/30/2018
# 136072                   WELLS FARGO & COMPANY            6/30/2018
# 136073                          Coinbase, Inc.            6/30/2018
# 136074                           EQUIFAX, INC.            6/30/2018
#
#        Company response to consumer Timely response?  Consumer disputed?  \
# 0           Closed with explanation              Yes                 NaN
# 1           Closed with explanation              Yes                 NaN
# 2           Closed with explanation              Yes                 NaN
# 3           Closed with explanation              Yes                 NaN
# 4           Closed with explanation              Yes                 NaN
# ...                             ...              ...                 ...
# 136070      Closed with explanation              Yes                 NaN
# 136071      Closed with explanation              Yes                 NaN
# 136072      Closed with explanation              Yes                 NaN
# 136073      Closed with explanation              Yes                 NaN
# 136074      Closed with explanation              Yes                 NaN
#
#        Complaint ID_y
# 0             2768809
# 1             2768922
# 2             2768940
# 3             2768821
# 4             2768974
# ...               ...
# 136070        2949947
# 136071        2950380
# 136072        2950472
# 136073        2950381
# 136074        2950356
#
# [136075 rows x 12 columns]

# %%
most_complaints_by_product = pd.DataFrame(all_complaints["Product"].value_counts().reset_index())
most_complaints_by_product
# Out:
#                                              Product  count
# 0  Credit reporting, credit repair services, or o...  57498
# 1                                    Debt collection  28415
# 2                                           Mortgage  13479
# 3                        Credit card or prepaid card  12530
# 4                        Checking or savings account  10611
# 5                                       Student loan   4701
# 6  Money transfer, virtual currency, or money ser...   3426
# 7                              Vehicle loan or lease   3162
# 8          Payday loan, title loan, or personal loan   2253

# %%
import matplotlib.pyplot as plt

# %%
plt.barh(most_complaints_by_product["Product"],most_complaints_by_product["count"])
plt.title("Number of Complaints by Product")
# Out:
# Text(0.5, 1.0, 'Number of Complaints by Product')

# %%
all_complaints["Date received_x"] = pd.to_datetime(all_complaints["Date received_x"])
all_complaints
# Out:
#        Date received_x                                            Product  \
# 0           2018-01-01                                    Debt collection
# 1           2018-01-01  Credit reporting, credit repair services, or o...
# 2           2018-01-01                        Credit card or prepaid card
# 3           2018-01-01  Credit reporting, credit repair services, or o...
# 4           2018-01-01  Credit reporting, credit repair services, or o...
# ...                ...                                                ...
# 136070      2018-06-30                                    Debt collection
# 136071      2018-06-30                        Credit card or prepaid card
# 136072      2018-06-30                        Checking or savings account
# 136073      2018-06-30  Money transfer, virtual currency, or money ser...
# 136074      2018-06-30                                    Debt collection
#
#                                      Company_x Complaint ID_x  \
# 0                       Messerli & Kramer P.A.        2768809
# 1                                EQUIFAX, INC.        2768922
# 2            CAPITAL ONE FINANCIAL CORPORATION        2768940
# 3                        WELLS FARGO & COMPANY        2768821
# 4       TRANSUNION INTERMEDIATE HOLDINGS, INC.        2768974
# ...                                        ...            ...
# 136070            National Credit Systems,Inc.        2949947
# 136071                    JPMORGAN CHASE & CO.        2950380
# 136072                   WELLS FARGO & COMPANY        2950472
# 136073                          Coinbase, Inc.        2950381
# 136074                           EQUIFAX, INC.        2950356
#
#                                             Company_ID Date received_y  \
# 0                       Messerli & Kramer P.A._2768809        1/1/2018
# 1                                EQUIFAX, INC._2768922        1/1/2018
# 2            CAPITAL ONE FINANCIAL CORPORATION_2768940        1/1/2018
# 3                        WELLS FARGO & COMPANY_2768821        1/1/2018
# 4       TRANSUNION INTERMEDIATE HOLDINGS, INC._2768974        1/1/2018
# ...                                                ...             ...
# 136070            National Credit Systems,Inc._2949947       6/30/2018
# 136071                    JPMORGAN CHASE & CO._2950380       6/30/2018
# 136072                   WELLS FARGO & COMPANY_2950472       6/30/2018
# 136073                          Coinbase, Inc._2950381       6/30/2018
# 136074                           EQUIFAX, INC._2950356       6/30/2018
#
#                                      Company_y Date sent to company  \
# 0                       Messerli & Kramer P.A.             1/1/2018
# 1                                EQUIFAX, INC.             1/1/2018
# 2            CAPITAL ONE FINANCIAL CORPORATION             1/1/2018
# 3                        WELLS FARGO & COMPANY             1/1/2018
# 4       TRANSUNION INTERMEDIATE HOLDINGS, INC.             1/1/2018
# ...                                        ...                  ...
# 136070            National Credit Systems,Inc.            6/30/2018
# 136071                    JPMORGAN CHASE & CO.            6/30/2018
# 136072                   WELLS FARGO & COMPANY            6/30/2018
# 136073                          Coinbase, Inc.            6/30/2018
# 136074                           EQUIFAX, INC.            6/30/2018
#
#        Company response to consumer Timely response?  Consumer disputed?  \
# 0           Closed with explanation              Yes                 NaN
# 1           Closed with explanation              Yes                 NaN
# 2           Closed with explanation              Yes                 NaN
# 3           Closed with explanation              Yes                 NaN
# 4           Closed with explanation              Yes                 NaN
# ...                             ...              ...                 ...
# 136070      Closed with explanation              Yes                 NaN
# 136071      Closed with explanation              Yes                 NaN
# 136072      Closed with explanation              Yes                 NaN
# 136073      Closed with explanation              Yes                 NaN
# 136074      Closed with explanation              Yes                 NaN
#
#        Complaint ID_y
# 0             2768809
# 1             2768922
# 2             2768940
# 3             2768821
# 4             2768974
# ...               ...
# 136070        2949947
# 136071        2950380
# 136072        2950472
# 136073        2950381
# 136074        2950356
#
# [136075 rows x 12 columns]

# %%
num_complaints_by_date = pd.DataFrame(all_complaints.groupby("Date received_x")["Complaint ID_x"].count().reset_index())
num_complaints_by_date
# Out:
#     Date received_x  Complaint ID_x
# 0        2018-01-01             271
# 1        2018-01-02             740
# 2        2018-01-03             990
# 3        2018-01-04             896
# 4        2018-01-05             831
# ..              ...             ...
# 176      2018-06-26             966
# 177      2018-06-27             814
# 178      2018-06-28             810
# 179      2018-06-29             628
# 180      2018-06-30             312
#
# [181 rows x 2 columns]

# %%
plt.figure(figsize=(20, 6))
plt.plot(num_complaints_by_date["Date received_x"],num_complaints_by_date["Complaint ID_x"])
plt.title("Number of Complaints by Date")
# Out:
# Text(0.5, 1.0, 'Number of Complaints by Date')

# %%
product_responses = pd.DataFrame(all_complaints.groupby("Product")["Timely response?"].value_counts().reset_index())
product_responses
# Out:
#                                               Product Timely response?  count
# 0                         Checking or savings account              Yes  10547
# 1                         Checking or savings account               No     64
# 2                         Credit card or prepaid card              Yes  12474
# 3                         Credit card or prepaid card               No     55
# 4   Credit reporting, credit repair services, or o...              Yes  57090
# 5   Credit reporting, credit repair services, or o...               No    401
# 6                                     Debt collection              Yes  27021
# 7                                     Debt collection               No   1333
# 8   Money transfer, virtual currency, or money ser...              Yes   3373
# 9   Money transfer, virtual currency, or money ser...               No     48
# 10                                           Mortgage              Yes  13265
# 11                                           Mortgage               No    212
# 12          Payday loan, title loan, or personal loan              Yes   2104
# 13          Payday loan, title loan, or personal loan               No    139
# 14                                       Student loan              Yes   4613
# 15                                       Student loan               No     59
# 16                              Vehicle loan or lease              Yes   3056
# 17                              Vehicle loan or lease               No    106

# %%
product_responses_yes = product_responses[product_responses["Timely response?"] == "Yes"]
product_responses_yes
# Out:
#                                               Product Timely response?  count
# 0                         Checking or savings account              Yes  10547
# 2                         Credit card or prepaid card              Yes  12474
# 4   Credit reporting, credit repair services, or o...              Yes  57090
# 6                                     Debt collection              Yes  27021
# 8   Money transfer, virtual currency, or money ser...              Yes   3373
# 10                                           Mortgage              Yes  13265
# 12          Payday loan, title loan, or personal loan              Yes   2104
# 14                                       Student loan              Yes   4613
# 16                              Vehicle loan or lease              Yes   3056

# %%
product_responses_no = product_responses[product_responses["Timely response?"] == "No"]
product_responses_no
# Out:
#                                               Product Timely response?  count
# 1                         Checking or savings account               No     64
# 3                         Credit card or prepaid card               No     55
# 5   Credit reporting, credit repair services, or o...               No    401
# 7                                     Debt collection               No   1333
# 9   Money transfer, virtual currency, or money ser...               No     48
# 11                                           Mortgage               No    212
# 13          Payday loan, title loan, or personal loan               No    139
# 15                                       Student loan               No     59
# 17                              Vehicle loan or lease               No    106

# %%
import numpy as np

# %%
plt.barh(product_responses_yes["Product"], product_responses_yes["count"], label = 'Yes') 

plt.title("Number of Timely Responses per Product")
# Out:
# Text(0.5, 1.0, 'Number of Timely Responses per Product')
